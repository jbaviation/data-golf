# %% [markdown]
# # Get Golf Data from datagolf.com
# This notebook is created to help make functions that end up in `get_golf_data.py`. The functions should be tested here and then added to the *.py* file for production.
#
# Getting data from [datagolf.com](https://datagolf.com/) will likely be more effective and consistent than building scrapers and crawlers from [pgatour.com](https://www.pgatour.com/).

# %%
import pandas as pd
import numpy as np
import requests
import pygolf
from importlib import reload
import csv

_ = reload(pygolf)

pd.options.display.min_rows = 25
pd.options.display.max_colwidth = 200
pd.options.display.max_columns = 50

# %%
dg = pygolf.datagolf()

test = dg.get_dg_rankings()

# %%
test
# Out:
#                 last_updated  am country  datagolf_rank  dg_id  \
# 0    2023-04-17 13:04:55 UTC   0     ESP              1  19195
# 1    2023-04-17 13:04:55 UTC   0     USA              2  18417
# 2    2023-04-17 13:04:55 UTC   0     USA              3  15466
# 3    2023-04-17 13:04:55 UTC   0     NIR              4  10091
# 4    2023-04-17 13:04:55 UTC   0     USA              5  19895
# 5    2023-04-17 13:04:55 UTC   0     USA              6  11676
# 6    2023-04-17 13:04:55 UTC   0     KOR              7  17488
# 7    2023-04-17 13:04:55 UTC   0     USA              8  14636
# 8    2023-04-17 13:04:55 UTC   0     USA              9  22085
# 9    2023-04-17 13:04:55 UTC   0     USA             10  26651
# 10   2023-04-17 13:04:55 UTC   0     ENG             11  17646
# 11   2023-04-17 13:04:55 UTC   0     NOR             12  18841
# ..                       ...  ..     ...            ...    ...
# 488  2023-04-17 13:04:55 UTC   0     USA            489  26657
# 489  2023-04-17 13:04:55 UTC   0     AUS            490  13342
# 490  2023-04-17 13:04:55 UTC   0     THA            491  14128
# 491  2023-04-17 13:04:55 UTC   0     USA            492  25027
# 492  2023-04-17 13:04:55 UTC   0     CAN            493  13404
# 493  2023-04-17 13:04:55 UTC   0     NOR            494  15651
# 494  2023-04-17 13:04:55 UTC   0     JPN            495  14209
# 495  2023-04-17 13:04:55 UTC   0     CHN            496  13026
# 496  2023-04-17 13:04:55 UTC   0     USA            497  11594
# 497  2023-04-17 13:04:55 UTC   0     USA            498  24956
# 498  2023-04-17 13:04:55 UTC   0     ESP            499  22259
# 499  2023-04-17 13:04:55 UTC   1     USA            500  25091
#
#      dg_skill_estimate  owgr_rank primary_tour    last_name suffix  \
# 0             2.603012          1          PGA         Rahm
# 1             2.529387          2          PGA    Scheffler
# 2             2.291553          4          PGA      Cantlay
# 3             2.182844          3          PGA      McIlroy
# 4             2.131035          5          PGA   Schauffele
# 5             1.931837         16          PGA        Finau
# 6             1.706381         17          PGA           Im
# 7             1.704234          9          PGA       Spieth
# 8             1.640405         13          PGA     Morikawa
# 9             1.632792         15          PGA        Young
# 10            1.605908          8          PGA  Fitzpatrick
# 11            1.542761         11          PGA      Hovland
# ..                 ...        ...          ...          ...    ...
# 488          -1.156798        501          KFT         Fisk
# 489          -1.157190        408          KFT       Gibson
# 490          -1.161136        419          ASA   Charoenkul
# 491          -1.163144        501          KFT    Hirschman
# 492          -1.163155        407          PGA       Gligic
# 493          -1.163565        501          KFT      Ventura
# 494          -1.165369        249          JPN       Kozuma
# 495          -1.170454        501          KFT        Zhang
# 496          -1.173914        501          KFT     McCarthy
# 497          -1.176426        501          KFT     Blanchet
# 498          -1.180412        296         EURO          Rey
# 499          -1.180957        501           AM         Choi
#
#         first_name
# 0              Jon
# 1          Scottie
# 2          Patrick
# 3             Rory
# 4           Xander
# 5             Tony
# 6          Sungjae
# 7           Jordan
# 8           Collin
# 9          Cameron
# 10         Matthew
# 11          Viktor
# ..             ...
# 488         Steven
# 489          Rhein
# 490           Gunn
# 491          Grant
# 492        Michael
# 493     Kristoffer
# 494      Jinichiro
# 495         Xinjun
# 496            Dan
# 497       Chandler
# 498  Alejandro Del
# 499            Sam
#
# [500 rows x 11 columns]
