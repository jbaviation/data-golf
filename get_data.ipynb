# %% [markdown]
# # Get Golf Data from datagolf.com
# This notebook is created to help make functions that end up in `get_golf_data.py`. The functions should be tested here and then added to the *.py* file for production.
#
# Getting data from [datagolf.com](https://datagolf.com/) will likely be more effective and consistent than building scrapers and crawlers from [pgatour.com](https://www.pgatour.com/).

# %%
import pandas as pd
import numpy as np
import requests
import pygolf
from importlib import reload
import csv

_ = reload(pygolf)

pd.options.display.min_rows = 25
pd.options.display.max_colwidth = 200
pd.options.display.max_columns = 50

# %%
dg = pygolf.datagolf()

test = dg.get_pre_tourney_predictions()

# %%
test
# Out:
#                         event_name              team_name p1_dg_id  p2_dg_id  \
# 0    Zurich Classic of New Orleans   Cantlay / Schauffele    15466     19895
# 1    Zurich Classic of New Orleans        Homa / Morikawa    17538     22085
# 2    Zurich Classic of New Orleans          Mitchell / Im    17365     17488
# 3    Zurich Classic of New Orleans              Kim / Kim    14609     24766
# 4    Zurich Classic of New Orleans  Kitayama / Montgomery    21891     25442
# 5    Zurich Classic of New Orleans        Hossler / Clark    15470     23604
# 6    Zurich Classic of New Orleans       Horschel / Burns    11276     19483
# 7    Zurich Classic of New Orleans         Suh / Theegala    22050     23014
# 8    Zurich Classic of New Orleans        Spaun / Buckley    17536     25363
# 9    Zurich Classic of New Orleans        Taylor / Hadwin    13126     13965
# 10   Zurich Classic of New Orleans               An / Kim    14459     21688
# 11   Zurich Classic of New Orleans          Detry / Perez    14181     20730
# ..                             ...                    ...      ...       ...
# 149  Zurich Classic of New Orleans          Stuard / Knox    13022     13831
# 150  Zurich Classic of New Orleans       Brown / Werenski    11330     19364
# 151  Zurich Classic of New Orleans        Thompson / Amin    12946  10058297
# 152  Zurich Classic of New Orleans        Points / Walker     6761      7293
# 153  Zurich Classic of New Orleans         Murray / Bryan    14655     21236
# 154  Zurich Classic of New Orleans       Barnes / Stanley     6846     12069
# 155  Zurich Classic of New Orleans             Kang / Bae     7881     10081
# 156  Zurich Classic of New Orleans       Garrigus / Ernst     6789     16711
# 157  Zurich Classic of New Orleans       Trahan / Collins     7236      7744
# 158  Zurich Classic of New Orleans       Ogilvy / Stadler     5698      7602
# 159  Zurich Classic of New Orleans           Daly / Duval      863      4761
# 160                                                  None     None      None
#
#     p1_country p2_country sample_size              last_updated  \
# 0          USA        USA         150  2023-04-17 18:11:07  UTC
# 1          USA        USA         150  2023-04-17 18:11:07  UTC
# 2          USA        KOR         150  2023-04-17 18:11:07  UTC
# 3          KOR        KOR         150  2023-04-17 18:11:07  UTC
# 4          USA        USA         150  2023-04-17 18:11:07  UTC
# 5          USA        USA         150  2023-04-17 18:11:07  UTC
# 6          USA        USA         150  2023-04-17 18:11:07  UTC
# 7          USA        USA         150  2023-04-17 18:11:07  UTC
# 8          USA        USA         150  2023-04-17 18:11:07  UTC
# 9          CAN        CAN         150  2023-04-17 18:11:07  UTC
# 10         KOR        KOR         150  2023-04-17 18:11:07  UTC
# 11         BEL        FRA         150  2023-04-17 18:11:07  UTC
# ..         ...        ...         ...                       ...
# 149        USA        SCO         150  2023-04-17 18:11:07  UTC
# 150        USA        USA         150  2023-04-17 18:11:07  UTC
# 151        USA        USA         150  2023-04-17 18:11:07  UTC
# 152        USA        USA         150  2023-04-17 18:11:07  UTC
# 153        USA        USA         150  2023-04-17 18:11:07  UTC
# 154        USA        USA         150  2023-04-17 18:11:07  UTC
# 155        KOR        KOR         150  2023-04-17 18:11:07  UTC
# 156        USA        USA         150  2023-04-17 18:11:07  UTC
# 157        USA        USA         150  2023-04-17 18:11:07  UTC
# 158        AUS        USA         150  2023-04-17 18:11:07  UTC
# 159        USA        USA         150  2023-04-17 18:11:07  UTC
# 160       None       None        None                      None
#
#                     model  make_cut    top_20    top_10                top_5  \
# 0    baseline_history_fit  0.867775  0.801275    0.6541             0.490475
# 1    baseline_history_fit  0.782475   0.65835  0.470175             0.303225
# 2    baseline_history_fit    0.7471  0.603675  0.404825             0.248225
# 3    baseline_history_fit   0.70265    0.5358  0.332725              0.19295
# 4    baseline_history_fit  0.673075  0.491725   0.29575               0.1678
# 5    baseline_history_fit    0.6844   0.50875   0.30885              0.17175
# 6    baseline_history_fit  0.668875   0.48425   0.28565               0.1556
# 7    baseline_history_fit   0.65335   0.46775   0.27525             0.148925
# 8    baseline_history_fit    0.6586     0.466    0.2724               0.1477
# 9    baseline_history_fit  0.629075  0.424275    0.2307              0.11875
# 10   baseline_history_fit    0.6139  0.405575  0.224125               0.1159
# 11   baseline_history_fit   0.59395   0.38045  0.203425  0.10099999999999999
# ..                    ...       ...       ...       ...                  ...
# 149              baseline   0.29415   0.08375  0.023625             0.006375
# 150              baseline    0.2839   0.07705  0.023175              0.00705
# 151              baseline  0.186825  0.033175  0.007525               0.0023
# 152              baseline    0.2305  0.049525  0.011075             0.002925
# 153              baseline   0.21745   0.04485  0.011675              0.00315
# 154              baseline  0.238175    0.0531  0.013875             0.003775
# 155              baseline  0.208225   0.03995   0.00895             0.001975
# 156              baseline    0.1406  0.017025    0.0033             0.000725
# 157              baseline    0.1131    0.0116   0.00205             0.000425
# 158              baseline  0.070075    0.0037    0.0005                5e-05
# 159              baseline  0.021125  0.000425   7.5e-05              2.5e-05
# 160                  None      None      None      None                 None
#
#           win
# 0      0.1904
# 1    0.085675
# 2       0.065
# 3     0.04375
# 4    0.038575
# 5    0.037825
# 6    0.032825
# 7    0.029875
# 8     0.02985
# 9    0.021275
# 10   0.020575
# 11   0.017825
# ..        ...
# 149  0.000625
# 150  0.000425
# 151  0.000225
# 152  0.000225
# 153    0.0002
# 154    0.0002
# 155   0.00015
# 156   7.5e-05
# 157   2.5e-05
# 158       0.0
# 159       0.0
# 160      None
#
# [161 rows x 14 columns]

# %%
# dfs = []
# for key, item in r.json().items():
#     df = pd.DataFrame(item)
#     df.name = key
#     dfs.append(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 dfs = []
#       2 for key, item in r.json().items():
# ----> 3     df = pd.DataFrame(item)
#       4     df.name = key
#       5     dfs.append(df)
#
# File ~/.local/share/virtualenvs/data_golf-kQt64669/lib/python3.10/site-packages/pandas/core/frame.py:816, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     813 # For data is scalar
#     814 else:
#     815     if index is None or columns is None:
# --> 816         raise ValueError("DataFrame constructor not properly called!")
#     818     index = ensure_index(index)
#     819     columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
